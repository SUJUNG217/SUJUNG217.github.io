# %%
import numpy as np
import pandas as pd

# %%
#Data Visualization
#Importing Dataset
data=pd.read_csv("train.csv")
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#Importing Python Modules
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use("ggplot")
plt.rcParams["figure.figsize"]=[6,3]
plt.rcParams["figure.dpi"]=80

# %%
#Missing Values
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data.isnull(),cbar=False,cmap="YlGnBu")
plt.ioff()

# %%
#Filling Age Missing Values
data["Title"]=0
for i in data:
    data["Title"]=data.Name.str.extract("([A-Za-z]+)\.")

# %%
pd.crosstab(data.Title,data.Sex).T.style.background_gradient(cmap="summer_r")
# Out:
# <style  type="text/css" >
#     #T_6aedcdf4_440a_11eb_8a23_5800e37d4806row0_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_6aedcdf4_440a_11eb_8a23_5800e37d4806row0_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_6aedcdf4_440a_11eb_8a23_5800e37d4806row0_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_6aedcdf4_440a_11eb_8a23_5800e37d4806row0_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_6aedcdf4_440a_11eb_8a23_5800e37d4806row0_col4 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_6aedcdf4_440a_11eb_8a23_5800e37d4806row0_col5 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_6aedcdf4_440a_11eb_8a23_5800e37d4806row0_col6 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_6aedcdf4_440a_11eb_8a23_5800e37d4806row0_col7 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_6aedcdf4_440a_11eb_8a23_5800e37d4806row0_col8 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_6aedcdf4_440a_11eb_8a23_5800e37d4806row0_col9 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_6aedcdf4_440a_11eb_8a23_5800e37d4806row0_col10 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_6aedcdf4_440a_11eb_8a23_5800e37d4806row0_col11 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_6aedcdf4_440a_11eb_8a23_5800e37d4806row0_col12 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_6aedcdf4_440a_11eb_8a23_5800e37d4806row0_col13 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_6aedcdf4_440a_11eb_8a23_5800e37d4806row0_col14 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_6aedcdf4_440a_11eb_8a23_5800e37d4806row0_col15 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_6aedcdf4_440a_11eb_8a23_5800e37d4806row0_col16 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_6aedcdf4_440a_11eb_8a23_5800e37d4806row1_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_6aedcdf4_440a_11eb_8a23_5800e37d4806row1_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_6aedcdf4_440a_11eb_8a23_5800e37d4806row1_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_6aedcdf4_440a_11eb_8a23_5800e37d4806row1_col3 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_6aedcdf4_440a_11eb_8a23_5800e37d4806row1_col4 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_6aedcdf4_440a_11eb_8a23_5800e37d4806row1_col5 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_6aedcdf4_440a_11eb_8a23_5800e37d4806row1_col6 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_6aedcdf4_440a_11eb_8a23_5800e37d4806row1_col7 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_6aedcdf4_440a_11eb_8a23_5800e37d4806row1_col8 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_6aedcdf4_440a_11eb_8a23_5800e37d4806row1_col9 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_6aedcdf4_440a_11eb_8a23_5800e37d4806row1_col10 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_6aedcdf4_440a_11eb_8a23_5800e37d4806row1_col11 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_6aedcdf4_440a_11eb_8a23_5800e37d4806row1_col12 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_6aedcdf4_440a_11eb_8a23_5800e37d4806row1_col13 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_6aedcdf4_440a_11eb_8a23_5800e37d4806row1_col14 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_6aedcdf4_440a_11eb_8a23_5800e37d4806row1_col15 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_6aedcdf4_440a_11eb_8a23_5800e37d4806row1_col16 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_6aedcdf4_440a_11eb_8a23_5800e37d4806" ><thead>    <tr>        <th class="index_name level0" >Title</th>        <th class="col_heading level0 col0" >Capt</th>        <th class="col_heading level0 col1" >Col</th>        <th class="col_heading level0 col2" >Countess</th>        <th class="col_heading level0 col3" >Don</th>        <th class="col_heading level0 col4" >Dr</th>        <th class="col_heading level0 col5" >Jonkheer</th>        <th class="col_heading level0 col6" >Lady</th>        <th class="col_heading level0 col7" >Major</th>        <th class="col_heading level0 col8" >Master</th>        <th class="col_heading level0 col9" >Miss</th>        <th class="col_heading level0 col10" >Mlle</th>        <th class="col_heading level0 col11" >Mme</th>        <th class="col_heading level0 col12" >Mr</th>        <th class="col_heading level0 col13" >Mrs</th>        <th class="col_heading level0 col14" >Ms</th>        <th class="col_heading level0 col15" >Rev</th>        <th class="col_heading level0 col16" >Sir</th>    </tr>    <tr>        <th class="index_name level0" >Sex</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6aedcdf4_440a_11eb_8a23_5800e37d4806level0_row0" class="row_heading level0 row0" >female</th>
#                         <td id="T_6aedcdf4_440a_11eb_8a23_5800e37d4806row0_col0" class="data row0 col0" >0</td>
#                         <td id="T_6aedcdf4_440a_11eb_8a23_5800e37d4806row0_col1" class="data row0 col1" >0</td>
#                         <td id="T_6aedcdf4_440a_11eb_8a23_5800e37d4806row0_col2" class="data row0 col2" >1</td>
#                         <td id="T_6aedcdf4_440a_11eb_8a23_5800e37d4806row0_col3" class="data row0 col3" >0</td>
#                         <td id="T_6aedcdf4_440a_11eb_8a23_5800e37d4806row0_col4" class="data row0 col4" >1</td>
#                         <td id="T_6aedcdf4_440a_11eb_8a23_5800e37d4806row0_col5" class="data row0 col5" >0</td>
#                         <td id="T_6aedcdf4_440a_11eb_8a23_5800e37d4806row0_col6" class="data row0 col6" >1</td>
#                         <td id="T_6aedcdf4_440a_11eb_8a23_5800e37d4806row0_col7" class="data row0 col7" >0</td>
#                         <td id="T_6aedcdf4_440a_11eb_8a23_5800e37d4806row0_col8" class="data row0 col8" >0</td>
#                         <td id="T_6aedcdf4_440a_11eb_8a23_5800e37d4806row0_col9" class="data row0 col9" >182</td>
#                         <td id="T_6aedcdf4_440a_11eb_8a23_5800e37d4806row0_col10" class="data row0 col10" >2</td>
#                         <td id="T_6aedcdf4_440a_11eb_8a23_5800e37d4806row0_col11" class="data row0 col11" >1</td>
#                         <td id="T_6aedcdf4_440a_11eb_8a23_5800e37d4806row0_col12" class="data row0 col12" >0</td>
#                         <td id="T_6aedcdf4_440a_11eb_8a23_5800e37d4806row0_col13" class="data row0 col13" >125</td>
#                         <td

# %%
data['Title'].replace(['Mlle','Mme','Ms','Dr','Major','Lady','Countess','Jonkheer','Col','Rev','Capt','Sir','Don'],['Miss','Miss','Miss','Mr','Mr','Mrs','Mrs','Other','Other','Other','Mr','Mr','Mr'],inplace=True)

# %%
pd.crosstab(data.Title,data.Sex).T.style.background_gradient(cmap="summer_r")
# Out:
# <style  type="text/css" >
#     #T_70a576f8_440a_11eb_930b_5800e37d4806row0_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_70a576f8_440a_11eb_930b_5800e37d4806row0_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_70a576f8_440a_11eb_930b_5800e37d4806row0_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_70a576f8_440a_11eb_930b_5800e37d4806row0_col3 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_70a576f8_440a_11eb_930b_5800e37d4806row0_col4 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_70a576f8_440a_11eb_930b_5800e37d4806row1_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_70a576f8_440a_11eb_930b_5800e37d4806row1_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_70a576f8_440a_11eb_930b_5800e37d4806row1_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_70a576f8_440a_11eb_930b_5800e37d4806row1_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_70a576f8_440a_11eb_930b_5800e37d4806row1_col4 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_70a576f8_440a_11eb_930b_5800e37d4806" ><thead>    <tr>        <th class="index_name level0" >Title</th>        <th class="col_heading level0 col0" >Master</th>        <th class="col_heading level0 col1" >Miss</th>        <th class="col_heading level0 col2" >Mr</th>        <th class="col_heading level0 col3" >Mrs</th>        <th class="col_heading level0 col4" >Other</th>    </tr>    <tr>        <th class="index_name level0" >Sex</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_70a576f8_440a_11eb_930b_5800e37d4806level0_row0" class="row_heading level0 row0" >female</th>
#                         <td id="T_70a576f8_440a_11eb_930b_5800e37d4806row0_col0" class="data row0 col0" >0</td>
#                         <td id="T_70a576f8_440a_11eb_930b_5800e37d4806row0_col1" class="data row0 col1" >186</td>
#                         <td id="T_70a576f8_440a_11eb_930b_5800e37d4806row0_col2" class="data row0 col2" >1</td>
#                         <td id="T_70a576f8_440a_11eb_930b_5800e37d4806row0_col3" class="data row0 col3" >127</td>
#                         <td id="T_70a576f8_440a_11eb_930b_5800e37d4806row0_col4" class="data row0 col4" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_70a576f8_440a_11eb_930b_5800e37d4806level0_row1" class="row_heading level0 row1" >male</th>
#                         <td id="T_70a576f8_440a_11eb_930b_5800e37d4806row1_col0" class="data row1 col0" >40</td>
#                         <td id="T_70a576f8_440a_11eb_930b_5800e37d4806row1_col1" class="data row1 col1" >0</td>
#                         <td id="T_70a576f8_440a_11eb_930b_5800e37d4806row1_col2" class="data row1 col2" >528</td>
#                         <td id="T_70a576f8_440a_11eb_930b_5800e37d4806row1_col3" class="data row1 col3" >0</td>
#                         <td id="T_70a576f8_440a_11eb_930b_5800e37d4806row1_col4" class="data row1 col4" >9</td>
#             </tr>
#     </tbody></table>

# %%
data.groupby("Title")["Age"].mean()
# Out:
# Title
# Master     4.574167
# Miss      21.860000
# Mr        32.739609
# Mrs       35.981818
# Other     45.888889
# Name: Age, dtype: float64

# %%
#Filling NaN Ages
data.loc[(data.Age.isnull())&(data.Title=="Master"),"Age"]=5
data.loc[(data.Age.isnull())&(data.Title=="Miss"),"Age"]=22
data.loc[(data.Age.isnull())&(data.Title=="Mr"),"Age"]=33
data.loc[(data.Age.isnull())&(data.Title=="Mrs"),"Age"]=36
data.loc[(data.Age.isnull())&(data.Title=="Other"),"Age"]=46

# %%
data.Age.isnull().any()
# Out:
# False

# %%
#Filling Embarked Nan
data["Embarked"].fillna("S",inplace=True)

# %%
data.Embarked.isnull().any()
# Out:
# False

# %%
#Heat Map
corrmat=data.corr()
fig=plt.figure(figsize=(10,7))
sns.heatmap(corrmat,vmax=1,square=True,annot=True,vmin=-1)
plt.show()

# %%
#Univariate Analysis
cols=data.columns
print(list(cols))
# Out:
# ['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'Title']

# %%
fig,ax=plt.subplots(2,4,figsize=(16,10))
sns.countplot("Survived",data=data,ax=ax[0][0])
sns.countplot("Pclass",data=data,ax=ax[0][1])
sns.countplot("Sex",data=data,ax=ax[0][2])
sns.countplot("SibSp",data=data,ax=ax[0][3])
sns.countplot("Parch",data=data,ax=ax[1][0])
sns.countplot("Embarked",data=data,ax=ax[1][1])
sns.distplot(data["Fare"],kde=True,ax=ax[1][2])

plt.tight_layout()

# %%
#Survived
f,ax=plt.subplots(1,2,figsize=(18,8))
data["Survived"].value_counts().plot.pie(ax=ax[0],explode=[0,0.1],shadow=True,autopct="%1.1f%%")
ax[0].set_title("Survived",fontsize=30)
ax[0].set_ylabel("Count")
sns.set(font="Verdana")
sns.set_style("ticks")
sns.countplot("Survived",hue="Sex",linewidth=2.5,edgecolor=".2",data=data,ax=ax[1])
plt.ioff()

# %%
#Groupby and Countplot
f,ax=plt.subplots(1,2,figsize=(18,8))
data[["Sex","Survived"]].groupby(["Sex"]).mean().plot.bar(ax=ax[0])
ax[0].set_title("Survived vs Sex")
sns.countplot("Sex",hue="Survived",data=data,ax=ax[1])
ax[1].set_title("Sex:Survived vs Dead")
plt.show()

# %%
#Strip+Survived+Age Plot
sns.stripplot(x="Survived",y="Age",data=data,jitter=True)
plt.show()   #pass

# %%
#Pclass
#Value Counts
data["Pclass"].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
#Group By+Count
data.groupby(["Pclass","Survived"])["Survived"].count()
# Out:
# Pclass  Survived
# 1       0            80
#         1           136
# 2       0            97
#         1            87
# 3       0           372
#         1           119
# Name: Survived, dtype: int64

# %%
#Count Plot
sns.countplot("Pclass",data=data)
plt.show()  #pass

# %%
#Countplot with Hue
sns.countplot("Pclass",hue="Survived",data=data)
plt.show()   #pass

# %%
#Pie Plot+Value Counts
data["Pclass"].value_counts().plot.pie(autopct="%1.1f%%",figsize=(10,7))
plt.show()   #pass

# %%
#Catplot
sns.catplot(x="Pclass",y="Survived",kind="bar",data=data)
plt.show()   #pass

# %%
#Pointplot
sns.catplot(x="Pclass",y="Survived",kind="point",data=data)
plt.show()   #pass

# %%
#Cat+Point+Hue Plot
sns.catplot(x="Pclass",y="Survived",hue="Sex",kind="point",data=data)
plt.show()   #pass

# %%
#Violin Plot
sns.catplot(x="Pclass",y="Survived",kind="violin",data=data)
plt.show()   #pass

# %%
#Sex
data["Sex"].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data["Sex"].value_counts().plot.pie(ax=ax[0],explode=[0,0.1],shadow=True,autopct="%1.1f%%")
ax[0].set_title("Sex",fontsize=30)
ax[0].set_ylabel("Count")
sns.set(font="Verdana")
sns.set_style("ticks")
sns.countplot("Sex",linewidth=2.5,edgecolor=".2",data=data,ax=ax[1])
plt.ioff()

# %%
#Groupby+Count Plot
data.groupby(["Sex","Survived"])["Survived"].count()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
#Count Plot
sns.countplot("Sex",data=data)
plt.show()   #pass

# %%
#Countplot+Hue
sns.countplot("Sex",hue="Survived",data=data)
plt.show()   #pass

# %%
#Pie Plot+Value Counts
data["Sex"].value_counts().plot.pie(autopct="%1.1f%%",figsize=(10,7))
plt.show()   #pass

# %%
#Cat+Sex+Survived+Bar
sns.catplot(x="Sex",y="Survived",kind="bar",data=data)
plt.show()   #pass

# %%
#Catplot+Sex+Survived+Bar+Pclass Hue Plot
sns.catplot(x="Sex",y="Survived",data=data,kind="bar",hue="Pclass")
plt.show()   #pass

# %%
#Catp+Sex+Survived+Bar+Pclass Column Plot
sns.catplot(x="Sex",y="Survived",data=data,kind="bar",col="Pclass")
plt.show()   #pass

# %%
#Catplot+Pclass+Survived+Bar+Sex Column Plot
sns.catplot(x="Pclass",y="Survived",data=data,kind="bar",col="Sex")
plt.show()   #pass

# %%
#Cat+Sex+Survived+Point Plot
sns.catplot(x="Sex",y="Survived",kind="point",data=data)
plt.show()   #pass

# %%
#Cat+Sex+Survived+Point+Pclass Hue Plot
sns.catplot(x="Sex",y="Survived",data=data,kind="point",hue="Pclass")
plt.show()   #pass

# %%
#Cat+Sex+Survived+Violin Plot
sns.catplot(x="Sex",y="Survived",data=data,kind="violin")
plt.show()   #pass

# %%
#Cat+Sex+Survived+Violin+Pclass Hue Plot
sns.catplot(x="Sex",y="Survived",kind="violin",data=data,hue="Pclass")
plt.show()   #pass

# %%
#Cat+Sex+Survived+Violin+Pclass Column Plot
sns.catplot(x="Sex",y="Survived",data=data,kind="violin",col="Pclass")
plt.show()   #pass

# %%
#Fare
print("Highest Fare was:",data["Fare"].max())
print("Lowest Fare was:",data["Fare"].min())
print("Average Fare was:",data["Fare"].mean())
# Out:
# Highest Fare was: 512.3292
# Lowest Fare was: 0.0
# Average Fare was: 32.2042079685746

# %%
#Histogram
data["Fare"].hist(bins=40,color="orange")
pass

# %%
#Distribution Plot
sns.distplot(data["Fare"])
plt.xlabel("Fare")
plt.show()

# %%
#KDE Plot
sns.kdeplot(data["Fare"],shade=True)
plt.xlabel("Fare")
plt.show()

# %%
#Classwise Fare Distribution
f,ax=plt.subplots(1,3,figsize=(20,8))
sns.distplot(data[data["Pclass"]==1].Fare,ax=ax[0])
ax[0].set_title("Fares in Pclass 1")
sns.distplot(data[data["Pclass"]==2].Fare,ax=ax[1])
ax[1].set_title("Fares in Pclass 2")
sns.distplot(data[data["Pclass"]==3].Fare,ax=ax[2])
ax[2].set_title("Fares in Pclass 3")
plt.show()

# %%
#Cat+Sex+Fare+Box Plot
sns.catplot(x="Sex",y="Fare",kind="box",data=data)
plt.show()   #pass

# %%
#Cat+Sex+Fare+Boxplot+Pclass Hue Plot
sns.catplot(x="Sex",y="Fare",data=data,kind="box",hue="Pclass")
plt.show()   #pass

# %%
#Cat+Sex+Fare+Box+Pclass Column Plot
sns.catplot(x="Sex",y="Fare",data=data,kind="box",col="Pclass")
plt.show()   #pass

# %%
#Cat+Sex+Fare+Boxen+Pclass Column Plot
sns.catplot(x="Sex",y="Fare",data=data,kind="boxen",col="Pclass")
plt.show()   #pass

# %%
#Cat+Pclass+Fare+Swarm+Sex Column Plot
sns.catplot(x="Pclass",y="Fare",kind="swarm",data=data,col='Sex')
plt.show()   #pass

# %%
#Catplot+Survived+Fare+Swarm+Sex Column
sns.catplot(x="Survived",y="Fare",data=data,kind="swarm",col="Sex")
plt.show()   #pass

# %%
#Cat+Survived+Fare+Swarm+Pclass Column Plot
sns.catplot(x="Survived",y="Fare",data=data,kind="swarm",col="Pclass")
plt.show()   #pass

# %%
#Joint+Age+Fare Plot
sns.jointplot(x="Age",y="Fare",data=data)
plt.show()   #pass

# %%
#Joint+Age+Fare+KDE Plot
sns.jointplot(x="Age",y="Fare",data=data,kind="kde")
plt.show()   #pass

# %%
#Relational+Age+Fare+Sex Hue Plot
sns.relplot(x="Age",y="Fare",data=data,hue="Sex")
plt.show()   #pass

# %%
#Relation+Age+Fare+Sex Column Plot
sns.relplot(x="Age",y="Fare",data=data,col="Sex")
plt.show()   #pass

# %%
#Relation+Age+Fare+Sex Row+Pclass Column Plot
sns.relplot(x="Age",y="Fare",data=data,row="Sex",col="Pclass")
plt.show()   #pass

# %%
#Fare Bin
data["Fare_Range"]=pd.qcut(data["Fare"],4)
data.groupby(["Fare_Range"])["Survived"].mean().to_frame().style.background_gradient(cmap="summer_r")
# Out:
# <style  type="text/css" >
#     #T_215b260c_441b_11eb_a7b0_5800e37d4806row0_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_215b260c_441b_11eb_a7b0_5800e37d4806row1_col0 {
#             background-color:  #b9dc66;
#             color:  #000000;
#         }    #T_215b260c_441b_11eb_a7b0_5800e37d4806row2_col0 {
#             background-color:  #54aa66;
#             color:  #000000;
#         }    #T_215b260c_441b_11eb_a7b0_5800e37d4806row3_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_215b260c_441b_11eb_a7b0_5800e37d4806" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Survived</th>    </tr>    <tr>        <th class="index_name level0" >Fare_Range</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_215b260c_441b_11eb_a7b0_5800e37d4806level0_row0" class="row_heading level0 row0" >(-0.001, 7.91]</th>
#                         <td id="T_215b260c_441b_11eb_a7b0_5800e37d4806row0_col0" class="data row0 col0" >0.197309</td>
#             </tr>
#             <tr>
#                         <th id="T_215b260c_441b_11eb_a7b0_5800e37d4806level0_row1" class="row_heading level0 row1" >(7.91, 14.454]</th>
#                         <td id="T_215b260c_441b_11eb_a7b0_5800e37d4806row1_col0" class="data row1 col0" >0.303571</td>
#             </tr>
#             <tr>
#                         <th id="T_215b260c_441b_11eb_a7b0_5800e37d4806level0_row2" class="row_heading level0 row2" >(14.454, 31.0]</th>
#                         <td id="T_215b260c_441b_11eb_a7b0_5800e37d4806row2_col0" class="data row2 col0" >0.454955</td>
#             </tr>
#             <tr>
#                         <th id="T_215b260c_441b_11eb_a7b0_5800e37d4806level0_row3" class="row_heading level0 row3" >(31.0, 512.329]</th>
#                         <td id="T_215b260c_441b_11eb_a7b0_5800e37d4806row3_col0" class="data row3 col0" >0.581081</td>
#             </tr>
#     </tbody></table>

# %%
data["Fare_Group"]=0
data.loc[data["Fare"]<=7.91,"Fare_Group"]=0
data.loc[(data["Fare"]>7.91)&(data["Fare"]<=14.454),"Fare_Group"]=1
data.loc[(data["Fare"]>14.454)&(data["Fare"]<=31),"Fare_Group"]=2
data.loc[(data["Fare"]>31)&(data["Fare"]<=513.329),"Fare_Group"]=3

# %%
sns.factorplot("Fare_Group","Survived",data=data,hue="Sex")
plt.show()   #pass
# Out:
# C:\anaconda\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.factorplot("Fare_Group","Survived",data=data,col="Pclass",hue="Sex")
plt.show()   #pass

# %%
#Age
print("Oldest Passenger was of:",data["Age"].max())
print("Youngest Passenger was of:",data["Age"].min())
print("Average Age on the ship:",data["Age"].mean())
# Out:
# Oldest Passenger was of: 80.0
# Youngest Passenger was of: 0.42
# Average Age on the ship: 29.841941638608304

# %%
plt.figure(figsize=(12,6))
data[data["Age"]<200000].Age.hist(bins=80,color="red")
plt.axvline(data[data["Age"]<=100].Age.mean(),color="black",linestyle="dashed",linewidth=3)
plt.xlabel("Age of Passengers",fontsize=20)
plt.ylabel("Number of People",fontsize=20)
plt.title("Age Distribution of Passengers on Titanic",fontsize=25)
plt.show()   #pass

# %%
#Survived By Age Distribution
f,ax=plt.subplots(1,2,figsize=(20,10))
data[data["Survived"]==0].Age.plot.hist(ax=ax[0],bins=20,edgecolor="black",color="red")
ax[0].set_title("Survived=0")
x1=list(range(0,85,5))
ax[0].set_xticks(x1)
data[data["Survived"]==1].Age.plot.hist(ax=ax[1],bins=20,edgecolor="black",color="green")
ax[1].set_title("Survived=1")
x2=list(range(0,85,5))
ax[1].set_xticks(x2)
plt.show()

# %%
#Age Binning
data["Age_band"]=0
data.loc[data["Age"]<=16,"Age_band"]=0
data.loc[(data["Age"]>16)&(data["Age"]<=32),"Age_band"]=1
data.loc[(data["Age"]>32)&(data["Age"]<=48),"Age_band"]=2
data.loc[(data["Age"]>48)&(data["Age"]<=64),"Age_band"]=3
data.loc[(data["Age"]>64),"Age_band"]=4
data.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked Title       Fare_Range  \
# 0      0  A/5 21171   7.2500   NaN        S    Mr   (-0.001, 7.91]
# 1      0   PC 17599  71.2833   C85        C   Mrs  (31.0, 512.329]
#
#    Fare_Group  Age_band
# 0           0         1
# 1           3         2

# %%
data["Age_band"].value_counts().to_frame().style.background_gradient(cmap="summer")
# Out:
# <style  type="text/css" >
#     #T_40ec6064_441f_11eb_b2db_5800e37d4806row0_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_40ec6064_441f_11eb_b2db_5800e37d4806row1_col0 {
#             background-color:  #d8ec66;
#             color:  #000000;
#         }    #T_40ec6064_441f_11eb_b2db_5800e37d4806row2_col0 {
#             background-color:  #40a066;
#             color:  #000000;
#         }    #T_40ec6064_441f_11eb_b2db_5800e37d4806row3_col0 {
#             background-color:  #289366;
#             color:  #000000;
#         }    #T_40ec6064_441f_11eb_b2db_5800e37d4806row4_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_40ec6064_441f_11eb_b2db_5800e37d4806" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Age_band</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_40ec6064_441f_11eb_b2db_5800e37d4806level0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_40ec6064_441f_11eb_b2db_5800e37d4806row0_col0" class="data row0 col0" >382</td>
#             </tr>
#             <tr>
#                         <th id="T_40ec6064_441f_11eb_b2db_5800e37d4806level0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_40ec6064_441f_11eb_b2db_5800e37d4806row1_col0" class="data row1 col0" >325</td>
#             </tr>
#             <tr>
#                         <th id="T_40ec6064_441f_11eb_b2db_5800e37d4806level0_row2" class="row_heading level0 row2" >0</th>
#                         <td id="T_40ec6064_441f_11eb_b2db_5800e37d4806row2_col0" class="data row2 col0" >104</td>
#             </tr>
#             <tr>
#                         <th id="T_40ec6064_441f_11eb_b2db_5800e37d4806level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_40ec6064_441f_11eb_b2db_5800e37d4806row3_col0" class="data row3 col0" >69</td>
#             </tr>
#             <tr>
#                         <th id="T_40ec6064_441f_11eb_b2db_5800e37d4806level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_40ec6064_441f_11eb_b2db_5800e37d4806row4_col0" class="data row4 col0" >11</td>
#             </tr>
#     </tbody></table>

# %%
#Factor+Age Band+Survived+Pclass Plot
sns.factorplot("Age_band","Survived",data=data,col="Pclass")
plt.show()

# %%
#Cat+Sex+Age+Box Plot
sns.catplot(x="Sex",y="Age",data=data,kind="box")
plt.show()   #pass

# %%
#Cat+Sex+Age+Box+Pclass Column Plot
sns.catplot(x="Sex",y="Age",data=data,kind="box",col="Pclass")
plt.show()   #pass

# %%
#Cat+Pclass+Age+Violin Plot
sns.catplot(x="Pclass",y="Age",kind="violin",data=data)
plt.show()   #pass

# %%
#Cat+Pclass+Age+Violin+Sex Hue Plot
sns.catplot(x="Pclass",y="Age",data=data,hue="Sex",kind="violin")
plt.show()   #pass

# %%
#Cat+Pclass+Age+Violin+Sex+Split Plot
sns.catplot(x="Pclass",y="Age",kind="violin",data=data,hue="Sex",split=True)
plt.show()   #pass

# %%
#Sibling and Spouse
data["FamilySize"]=data["SibSp"]+data["Parch"]+1
sns.countplot("FamilySize",data=data)
plt.show()   #pass

# %%
#Bar and Factor plot SibSp Survived
pd.crosstab(data.SibSp,data.Pclass).style.background_gradient(cmap="summer_r")
# Out:
# <style  type="text/css" >
#     #T_4d891114_442a_11eb_8277_5800e37d4806row0_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_4d891114_442a_11eb_8277_5800e37d4806row0_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_4d891114_442a_11eb_8277_5800e37d4806row0_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_4d891114_442a_11eb_8277_5800e37d4806row1_col0 {
#             background-color:  #7bbd66;
#             color:  #000000;
#         }    #T_4d891114_442a_11eb_8277_5800e37d4806row1_col1 {
#             background-color:  #8ac466;
#             color:  #000000;
#         }    #T_4d891114_442a_11eb_8277_5800e37d4806row1_col2 {
#             background-color:  #c6e266;
#             color:  #000000;
#         }    #T_4d891114_442a_11eb_8277_5800e37d4806row2_col0 {
#             background-color:  #f6fa66;
#             color:  #000000;
#         }    #T_4d891114_442a_11eb_8277_5800e37d4806row2_col1 {
#             background-color:  #eef666;
#             color:  #000000;
#         }    #T_4d891114_442a_11eb_8277_5800e37d4806row2_col2 {
#             background-color:  #f8fc66;
#             color:  #000000;
#         }    #T_4d891114_442a_11eb_8277_5800e37d4806row3_col0 {
#             background-color:  #fafc66;
#             color:  #000000;
#         }    #T_4d891114_442a_11eb_8277_5800e37d4806row3_col1 {
#             background-color:  #fdfe66;
#             color:  #000000;
#         }    #T_4d891114_442a_11eb_8277_5800e37d4806row3_col2 {
#             background-color:  #fafc66;
#             color:  #000000;
#         }    #T_4d891114_442a_11eb_8277_5800e37d4806row4_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_4d891114_442a_11eb_8277_5800e37d4806row4_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_4d891114_442a_11eb_8277_5800e37d4806row4_col2 {
#             background-color:  #f6fa66;
#             color:  #000000;
#         }    #T_4d891114_442a_11eb_8277_5800e37d4806row5_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_4d891114_442a_11eb_8277_5800e37d4806row5_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_4d891114_442a_11eb_8277_5800e37d4806row5_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_4d891114_442a_11eb_8277_5800e37d4806row6_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_4d891114_442a_11eb_8277_5800e37d4806row6_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_4d891114_442a_11eb_8277_5800e37d4806row6_col2 {
#             background-color:  #fefe66;
#             color:  #000000;
#         }</style><table id="T_4d891114_442a_11eb_8277_5800e37d4806" ><thead>    <tr>        <th class="index_name level0" >Pclass</th>        <th class="col_heading level0 col0" >1</th>        <th class="col_heading level0 col1" >2</th>        <th class="col_heading level0 col2" >3</th>    </tr>    <tr>        <th class="index_name level0" >SibSp</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4d891114_442a_11eb_8277_5800e37d4806level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_4d891114_442a_11eb_8277_5800e37d4806row0_col0" class="data row0 col0" >137</td>
#                         <td id="T_4d891114_442a_11eb_8277_5800e37d4806row0_col1" class="data row0 col1" >120</td>
#                         <td id="T_4d891114_442a_11eb_8277_5800e37d4806row0_col2" class="data row0 col2" >351</td>
#             </tr>
#             <tr>
#                         <th id="T_4d891114_442a_11eb_8277_5800e37d4806level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_4d891114_442a_11eb_8277_5800e37d4806row1_col0" class="data row1 col0" >71</td>
#                         <td id="T_4d891114_442a_11eb_8277_5800e37d4806row1_col1" class="data row1 col1" >55</td>
#                         <td id="T_4d891114_442a_11eb_8277_5800e37d4806row1_col2" class="data row1 col2" >83</td>
#             </tr>
#             <tr>
#                         <th id="T_4d891114_442a_11eb_8277_5800e37d4806level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_4d891114_442a_11eb_8277_5800e37d4806row2_col0" class="data row2 col0" >5</td>
#                         <td id="T_4d891114_442a_11eb_8277_5800e37d4806row2_col1" class="data row2 col1" >8</td>
#                         <td id="T_4d891114_442a_11eb_8277_5800e37d4806row2_col2" class="data row2 col2" >15</td>
#             </tr>
#             <tr>
#                         <th id="T_4d891114_442a_11eb_8277_5800e37d4806level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_4d891114_442a_11eb_8277_5800e37d4806row3_col0" class="data row3 col0" >3</td>
#                         <td id="T_4d891114_442a_11eb_8277_5800e37d4806row3_col1" class="data row3 col1" >1</td>
#                         <td id="T_4d891114_442a_11eb_8277_5800e37d4806row3_col2" class="data row3 col2" >12</td>
#             </tr>
#             <tr>
#                         <th id="T_4d891114_442a_11eb_8277_5800e37d4806level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_4d891114_442a_11eb_8277_5800e37d4806row4_col0" class="data row4 col0" >0</td>
#                         <td id="T_4d891114_442a_11eb_8277_5800e37d4806row4_col1" class="data row4 col1" >0</td>
#                         <td id="T_4d891114_442a_11eb_8277_5800e37d4806row4_col2" class="data row4 col2" >18</td>
#             </tr>
#             <tr>
#                         <th id="T_4d891114_442a_11eb_8277_5800e37d4806level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_4d891114_442a_11eb_8277_5800e37d4806row5_col0" class="data row5 col0" >0</td>
#                         <td id="T_4d891114_442a_11eb_8277_5800e37d4806row5_col1" class="data row5 col1" >0</td>
#                         <td id="T_4d891114_442a_11eb_8277_5800e37d4806row5_col2" class="data row5 col2" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_4d891114_442a_11eb_8277_5800e37d4806level0_row6" class="row_heading level0 row6" >8</th>
#                         <td id="T_4d891114_442a_11eb_8277_5800e37d4806row6_col0" class="data row6 col0" >0</td>
#                         <td id="T_4d891114_442a_11eb_8277_5800e37d4806row6_col1" class="data row6 col1" >0</td>
#                         <td id="T_4d891114_442a_11eb_8277_5800e37d4806row6_col2" class="data row6 col2" >7</td>
#             </tr>
#     </tbody></table>

# %%
f,ax=plt.subplots(1,2,figsize=(20,8))
sns.barplot("SibSp","Survived",data=data,ax=ax[0])
ax[0].set_title("SibSp vs Survived")
sns.factorplot("SibSp","Survived",data=data,ax=ax[1])
ax[1].set_title("SibSp vs Survived")
plt.close(2)
plt.show()
# Out:
# C:\anaconda\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
#Parents and Children(Parch)
pd.crosstab(data.Parch,data.Pclass).style.background_gradient(cmap="summer_r")
# Out:
# <style  type="text/css" >
#     #T_a3faac52_442a_11eb_b903_5800e37d4806row0_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_a3faac52_442a_11eb_b903_5800e37d4806row0_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_a3faac52_442a_11eb_b903_5800e37d4806row0_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_a3faac52_442a_11eb_b903_5800e37d4806row1_col0 {
#             background-color:  #cfe766;
#             color:  #000000;
#         }    #T_a3faac52_442a_11eb_b903_5800e37d4806row1_col1 {
#             background-color:  #c2e066;
#             color:  #000000;
#         }    #T_a3faac52_442a_11eb_b903_5800e37d4806row1_col2 {
#             background-color:  #dbed66;
#             color:  #000000;
#         }    #T_a3faac52_442a_11eb_b903_5800e37d4806row2_col0 {
#             background-color:  #dfef66;
#             color:  #000000;
#         }    #T_a3faac52_442a_11eb_b903_5800e37d4806row2_col1 {
#             background-color:  #e1f066;
#             color:  #000000;
#         }    #T_a3faac52_442a_11eb_b903_5800e37d4806row2_col2 {
#             background-color:  #e3f166;
#             color:  #000000;
#         }    #T_a3faac52_442a_11eb_b903_5800e37d4806row3_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_a3faac52_442a_11eb_b903_5800e37d4806row3_col1 {
#             background-color:  #fcfe66;
#             color:  #000000;
#         }    #T_a3faac52_442a_11eb_b903_5800e37d4806row3_col2 {
#             background-color:  #fefe66;
#             color:  #000000;
#         }    #T_a3faac52_442a_11eb_b903_5800e37d4806row4_col0 {
#             background-color:  #fefe66;
#             color:  #000000;
#         }    #T_a3faac52_442a_11eb_b903_5800e37d4806row4_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_a3faac52_442a_11eb_b903_5800e37d4806row4_col2 {
#             background-color:  #fefe66;
#             color:  #000000;
#         }    #T_a3faac52_442a_11eb_b903_5800e37d4806row5_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_a3faac52_442a_11eb_b903_5800e37d4806row5_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_a3faac52_442a_11eb_b903_5800e37d4806row5_col2 {
#             background-color:  #fdfe66;
#             color:  #000000;
#         }    #T_a3faac52_442a_11eb_b903_5800e37d4806row6_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_a3faac52_442a_11eb_b903_5800e37d4806row6_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_a3faac52_442a_11eb_b903_5800e37d4806row6_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }</style><table id="T_a3faac52_442a_11eb_b903_5800e37d4806" ><thead>    <tr>        <th class="index_name level0" >Pclass</th>        <th class="col_heading level0 col0" >1</th>        <th class="col_heading level0 col1" >2</th>        <th class="col_heading level0 col2" >3</th>    </tr>    <tr>        <th class="index_name level0" >Parch</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a3faac52_442a_11eb_b903_5800e37d4806level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_a3faac52_442a_11eb_b903_5800e37d4806row0_col0" class="data row0 col0" >163</td>
#                         <td id="T_a3faac52_442a_11eb_b903_5800e37d4806row0_col1" class="data row0 col1" >134</td>
#                         <td id="T_a3faac52_442a_11eb_b903_5800e37d4806row0_col2" class="data row0 col2" >381</td>
#             </tr>
#             <tr>
#                         <th id="T_a3faac52_442a_11eb_b903_5800e37d4806level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_a3faac52_442a_11eb_b903_5800e37d4806row1_col0" class="data row1 col0" >31</td>
#                         <td id="T_a3faac52_442a_11eb_b903_5800e37d4806row1_col1" class="data row1 col1" >32</td>
#                         <td id="T_a3faac52_442a_11eb_b903_5800e37d4806row1_col2" class="data row1 col2" >55</td>
#             </tr>
#             <tr>
#                         <th id="T_a3faac52_442a_11eb_b903_5800e37d4806level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_a3faac52_442a_11eb_b903_5800e37d4806row2_col0" class="data row2 col0" >21</td>
#                         <td id="T_a3faac52_442a_11eb_b903_5800e37d4806row2_col1" class="data row2 col1" >16</td>
#                         <td id="T_a3faac52_442a_11eb_b903_5800e37d4806row2_col2" class="data row2 col2" >43</td>
#             </tr>
#             <tr>
#                         <th id="T_a3faac52_442a_11eb_b903_5800e37d4806level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_a3faac52_442a_11eb_b903_5800e37d4806row3_col0" class="data row3 col0" >0</td>
#                         <td id="T_a3faac52_442a_11eb_b903_5800e37d4806row3_col1" class="data row3 col1" >2</td>
#                         <td id="T_a3faac52_442a_11eb_b903_5800e37d4806row3_col2" class="data row3 col2" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_a3faac52_442a_11eb_b903_5800e37d4806level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_a3faac52_442a_11eb_b903_5800e37d4806row4_col0" class="data row4 col0" >1</td>
#                         <td id="T_a3faac52_442a_11eb_b903_5800e37d4806row4_col1" class="data row4 col1" >0</td>
#                         <td id="T_a3faac52_442a_11eb_b903_5800e37d4806row4_col2" class="data row4 col2" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_a3faac52_442a_11eb_b903_5800e37d4806level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_a3faac52_442a_11eb_b903_5800e37d4806row5_col0" class="data row5 col0" >0</td>
#                         <td id="T_a3faac52_442a_11eb_b903_5800e37d4806row5_col1" class="data row5 col1" >0</td>
#                         <td id="T_a3faac52_442a_11eb_b903_5800e37d4806row5_col2" class="data row5 col2" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_a3faac52_442a_11eb_b903_5800e37d4806level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_a3faac52_442a_11eb_b903_5800e37d4806row6_col0" class="data row6 col0" >0</td>
#                         <td id="T_a3faac52_442a_11eb_b903_5800e37d4806row6_col1" class="data row6 col1" >0</td>
#                         <td id="T_a3faac52_442a_11eb_b903_5800e37d4806row6_col2" class="data row6 col2" >1</td>
#             </tr>
#     </tbody></table>

# %%
f,ax=plt.subplots(1,2,figsize=(20,8))
sns.barplot("Parch","Survived",data=data,ax=ax[0])
ax[0].set_title("Parch vs Survived")
sns.factorplot("Parch","Survived",data=data,ax=ax[1])
ax[1].set_title("Parch vs Survived")
plt.close(2)
plt.show()

# %%
#Embarked
data["Embarked"].value_counts()
# Out:
# S    646
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
#Count Plot
sns.countplot("Embarked",data=data)
plt.show()   #pass

# %%
sns.countplot("Embarked",data=data,hue="Survived")
plt.show() #pass

# %%
sns.catplot(x="Embarked",y="Survived",data=data,kind="bar");

# %%
#Cat+Embarked+Fare+Bar+Sex Plot
sns.catplot(x="Embarked",y="Fare",data=data,kind="bar",hue="Sex");

# %%
#Percentage Survived by Port
sns.factorplot("Embarked","Survived",data=data)
fig=plt.gcf()
fig.set_size_inches(5,3)
plt.show()

# %%
#Count Plot Based On Embarked,Sex and Class
f,ax=plt.subplots(2,2,figsize=(20,15))
sns.countplot("Embarked",data=data,ax=ax[0,0])
ax[0,0].set_title("No.Of Passengers Boarded")
sns.countplot("Embarked",data=data,hue="Sex",ax=ax[0,1])
ax[0,1].set_title("Male-Female Split for Embarked")
sns.countplot("Embarked",data=data,hue="Survived",ax=ax[1,0])
ax[1,0].set_title("Embarked vs Survived")
sns.countplot("Embarked",data=data,hue="Pclass",ax=ax[1,1])
ax[1,1].set_title("Embarked vs Pclass")
plt.subplots_adjust(wspace=0.2,hspace=0.5)
plt.show()

# %%
#Factor Plot based on Class,Survival,Sex and Embarked
sns.factorplot("Pclass","Survived",hue="Sex",col="Embarked",data=data)
plt.show()

# %%
#Who
import re
plt.figure(figsize=(12,5))
sns.countplot(x="Title",data=data,palette="hls")
plt.xlabel("Title",fontsize=16)
plt.ylabel("Count",fontsize=16)
plt.title("Title Name Count",fontsize=20)
plt.xticks(rotation=45)
plt.show()

# %%
Title_Dictionary = {
        "Capt":       "Officer",
        "Col":        "Officer",
        "Major":      "Officer",
        "Dr":         "Officer",
        "Rev":        "Officer",
        "Jonkheer":   "Royalty",
        "Don":        "Royalty",
        "Sir" :       "Royalty",
        "the Countess":"Royalty",
        "Dona":       "Royalty",
        "Lady" :      "Royalty",
        "Mme":        "Mrs",
        "Ms":         "Mrs",
        "Mrs" :       "Mrs",
        "Mlle":       "Miss",
        "Miss" :      "Miss",
        "Mr" :        "Mr",
        "Master" :    "Master"
                   }
data["Title"]=data.Title.map(Title_Dictionary)

# %%
print("Chance of Survival based on Titles:")
print(data.groupby("Title")["Survived"].mean())
sns.countplot(x="Title",data=data,palette="hls",hue="Survived")
plt.xlabel("Title",fontsize=15)
plt.ylabel("Count",fontsize=15)
plt.title("Count by Title",fontsize=20)
plt.xticks(rotation=30)
plt.show()
# Out:
# Chance of Survival based on Titles:
# Title
# Master    0.575000
# Miss      0.704301
# Mr        0.162571
# Mrs       0.795276
# Name: Survived, dtype: float64

# %%
#Feature Emgineering
#Converting and String to Numerical Values
data["Sex"]=data["Sex"].astype(str)
data["Embarked"]=data["Embarked"].astype(str)
data["Sex"].replace(["male","female"],[0,1],inplace=True)
data["Embarked"].replace(["S","C","Q"],[0,1,2],inplace=True)
data["Title"].replace(["Mr","Mrs","Miss","Master","Other"],[0,1,2,3,4],inplace=True)
data.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1      0
#
#       Ticket     Fare Cabin  Embarked Title       Fare_Range  Fare_Group  \
# 0  A/5 21171   7.2500   NaN         0     0   (-0.001, 7.91]           0
# 1   PC 17599  71.2833   C85         1     1  (31.0, 512.329]           3
#
#    Age_band  FamilySize
# 0         1           2
# 1         2           2

# %%
#Dropping Unwanted Columns
df=data.copy()
df.drop(["Name","Age","Ticket","Fare","Cabin","Fare_Range","PassengerId"],axis=1,inplace=True)
sns.heatmap(df.corr(),annot=True,cmap="RdYlGn",linewidth=0.2,annot_kws={'size':20})
fig=plt.gcf()
fig.set_size_inches(18,15)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show()

# %%
df.drop(["SibSp","Parch"],axis=1,inplace=True)
df.head()
# Out:
#    Survived  Pclass  Sex  Embarked Title  Fare_Group  Age_band  FamilySize
# 0         0       3    0         0     0           0         1           2
# 1         1       1    1         1     1           3         2           2
# 2         1       3    1         0     2           1         1           1
# 3         1       1    1         0     1           3         2           2
# 4         0       3    0         0     0           1         2           1

# %%
#Dropping Missing Values
df.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Embarked      0
# Title         9
# Fare_Group    0
# Age_band      0
# FamilySize    0
# dtype: int64

# %%
df=df.dropna()

# %%
#Pair Plot
plt.figure(figsize=(12,6))
sns.pairplot(data,vars=["Pclass","Fare","Age","Sex","Embarked"],hue="Survived")
plt.tight_layout(),plt.ioff()
plt.show() #pass

# %%
#Model Build
#Importing Modules
from sklearn.linear_model import LogisticRegression
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import confusion_matrix

# %%
#Creating Matrix of Features
X=df.drop(labels="Survived",axis=1)
y=df["Survived"]

# %%
#Test Train Split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.1,random_state=1234,stratify=y)
print("Trainig Set:",len(X_train))
print("Test Set:",len(X_test))
print("Training Labels:",len(y_train))
print("Test Labels:",len(y_test))
# Out:
# Trainig Set: 793
# Test Set: 89
# Training Labels: 793
# Test Labels: 89

# %%
#Linear Support Vector Machine(SVM)
model=svm.SVC(kernel="linear",C=0.1,gamma=0.1)
model.fit(X_train,y_train)
prediction1=model.predict(X_test)
print("Accuracy for linear SVM is",metrics.accuracy_score(prediction1,y_test))
# Out:
# Accuracy for linear SVM is 0.8426966292134831

# %%
#Radial SVM(rbf-SVM)
model=svm.SVC(kernel="rbf",C=0.1,gamma=0.1)
model.fit(X_train,y_train)
prediction2=model.predict(X_test)
print("Accuracy of rbf SVM is:",metrics.accuracy_score(prediction2,y_test))
# Out:
# Accuracy of rbf SVM is: 0.8426966292134831

# %%
#Decision Tree
model=DecisionTreeClassifier()
model.fit(X_train,y_train)
prediction3=model.predict(X_test)
print("Acuuracy of the Decision Tree is:",metrics.accuracy_score(prediction3,y_test))
# Out:
# Acuuracy of the Decision Tree is: 0.8314606741573034

# %%
#Random Forest
model=RandomForestClassifier()
model.fit(X_train,y_train)
prediction4=model.predict(X_test)
print("Accuracy of the Random Forest is:",metrics.accuracy_score(prediction4,y_test))
# Out:
# Accuracy of the Random Forest is: 0.8202247191011236
# C:\anaconda\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
#Gaussian Naive Bayes
model=GaussianNB()
model.fit(X_train,y_train)
prediction5=model.predict(X_test)
print("Accuracy of the Naive Bayes is:",metrics.accuracy_score(prediction5,y_test))
# Out:
# Accuracy of the Naive Bayes is: 0.797752808988764

# %%
#Logistic Regression
model=LogisticRegression()
model.fit(X_train,y_train)
prediction6=model.predict(X_test)
print("Accuracy of Logistic Regression is:",metrics.accuracy_score(prediction6,y_test))
# Out:
# Accuracy of Logistic Regression is: 0.7865168539325843
# C:\anaconda\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
#K Nearest Neighbors(KNN)
model=KNeighborsClassifier()
model.fit(X_train,y_train)
prediction7=model.predict(X_test)
print("Accuracy of KNN is:",metrics.accuracy_score(prediction7,y_test))
# Out:
# Accuracy of KNN is: 0.797752808988764
